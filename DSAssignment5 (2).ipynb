# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS ON A DATASET ##

# %% [markdown]
# #### Objective:
# The main goal of this assignment is to conduct a thorough exploratory analysis of the "cardiographic.csv" dataset to uncover insights, identify patterns, and understand the dataset's underlying structure. You will use statistical summaries, visualizations, and data manipulation techniques to explore the dataset comprehensively.
# ####

# %% [markdown]
# ## 1 Import Libraries
# ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 2 Load Data ##

# %%
df =pd.read_csv("D:\DS.24th July Banner Batch\Cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# 0      0.5  43.000000   2.4   64.0  0.999926  2.000000
# 1      2.1   0.000000  10.4  130.0  0.000000  1.000000
# 2      2.1   0.000000  13.4  130.0  0.000000  1.000000
# 3      2.4   0.000000  23.0  117.0  1.000000  1.000000
# 4      2.4   0.000000  19.9  117.0  1.000000  1.000000
# ...    ...        ...   ...    ...       ...       ...
# 2121   0.2  25.000000   7.2   40.0  0.000000  2.000000
# 2122   0.4  22.000000   7.1   66.0  1.000000  2.000000
# 2123   0.4  20.000000   6.1   67.0  1.000000  1.990464
# 2124   0.4  27.000000   7.0   66.0  1.000000  2.000000
# 2125   0.4  35.857183   5.0   42.0  0.000000  1.000000
#
# [2126 rows x 14 columns]

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# min      -0.001353    -0.005348   -63.000000    -6.600000   -91.000000
# 25%       0.000000     0.000000    32.000000     0.700000     0.000000
# 50%       0.000000     0.000000    49.000000     1.200000     0.000000
# 75%       0.000000     0.000000    61.000000     1.700000    11.000000
# max       0.002706     0.010695   162.000000    13.800000   182.000000
#
#               MLTV        Width     Tendency          NSP
# count  2105.000000  2105.000000  2105.000000  2105.000000
# mean      8.284887    70.429260     0.316371     1.304507
# std       7.772858    42.931822     0.645622     0.644619
# min     -50.700000  -174.000000    -3.000000    -1.025988
# 25%       4.600000    37.000000     0.000000     1.000000
# 50%       7.400000    67.000000     0.000000     1.000000
# 75%      10.900000   100.000000     1.000000     1.000000
# max     101.400000   357.000000     3.000000     5.000000

# %%
df.shape
# Out:
# (2126, 14)

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.duplicated()  #False =0 True=1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2121    False
# 2122    False
# 2123    False
# 2124    False
# 2125    False
# Length: 2126, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %% [markdown]
# ## Data Visualization ##

# %% [markdown]
# #### LB - Likely stands for "Baseline Fetal Heart Rate (FHR)" which represents the average fetal heart rate over a period. ####

# %%
df["LB"].hist()
plt.show()

# %% [markdown]
# #### 2.	AC - Could represent "Accelerations" in the FHR. Accelerations are usually a sign of fetal well-being. ####

# %%
df["AC"].hist()
plt.show()

# %% [markdown]
# #### 3.	FM - May indicate "Fetal Movements" detected by the monitor. ####

# %%
df["FM"].hist()
plt.show()

# %% [markdown]
# #### 4.	UC - Likely denotes "Uterine Contractions", which can impact the FHR pattern. ####

# %%
df["UC"].hist()
plt.show()

# %% [markdown]
# #### 5.	DL - Could stand for "Decelerations Late" with respect to uterine contractions, which can be a sign of fetal distress. ####

# %%
df["DL"].hist()
plt.show()

# %% [markdown]
# #### 6.	DS - May represent "Decelerations Short" or decelerations of brief duration. ####

# %%
df["DS"].hist()
plt.show()

# %% [markdown]
# #### 7.	DP - Could indicate "Decelerations Prolonged", or long-lasting decelerations. ####

# %%
df["DP"].hist()
plt.show()

# %% [markdown]
# #### 8.	ASTV - Might refer to "Percentage of Time with Abnormal Short Term Variability" in the FHR. ####

# %%
df["ASTV"].hist()
plt.show()

# %% [markdown]
# #### 9.	MSTV - Likely stands for "Mean Value of Short Term Variability" in the FHR. ####

# %%
df["MSTV"].hist()
plt.show()

# %% [markdown]
# #### 10.	ALTV - Could represent "Percentage of Time with Abnormal Long Term Variability" in the FHR. ####

# %%
df["ALTV"].hist()
plt.show()

# %% [markdown]
# #### 11.	MLTV - Might indicate "Mean Value of Long Term Variability" in the FHR. ####

# %%
df["Width"].hist()
plt.show()

# %%
df["Tendency"].hist()
plt.show()

# %%
df["NSP"].hist()
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
sns.histplot(df)
plt.show()

# %%
sns.boxplot(df)
plt.show()

# %%
#df.corr()
df.corr()
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.063830  0.018777 -0.166570 -0.126959 -0.005438
# AC       -0.063830  1.000000  0.009433  0.072012 -0.093507 -0.033623
# FM        0.018777  0.009433  1.000000 -0.053226  0.009718  0.029901
# UC       -0.166570  0.072012 -0.053226  1.000000  0.190128 -0.006937
# DL       -0.126959 -0.093507  0.009718  0.190128  1.000000  0.058625
# DS       -0.005438 -0.033623  0.029901 -0.006937  0.058625  1.000000
# DP       -0.047724 -0.084590  0.121284  0.070658  0.145425  0.004285
# ASTV      0.242625 -0.231103 -0.032691 -0.181161 -0.069361  0.008452
# MSTV     -0.170473  0.134168  0.017055  0.189406  0.410102  0.016163
# ALTV      0.210728 -0.271390 -0.011936 -0.227304 -0.186967 -0.004398
# MLTV     -0.003457 -0.106529 -0.006237 -0.049460 -0.165750  0.034349
# Width    -0.118425  0.238436  0.097213  0.107397  0.410031  0.040832
# Tendency  0.236864  0.032481 -0.018339 -0.066610 -0.023569 -0.015398
# NSP       0.131843 -0.316941  0.074054 -0.185411  0.025427  0.065400
#
#                 DP      ASTV      MSTV      ALTV      MLTV     Width  \
# LB       -0.047724  0.242625 -0.170473  0.210728 -0.003457 -0.118425
# AC       -0.084590 -0.231103  0.134168 -0.271390 -0.106529  0.238436
# FM        0.121284 -0.032691  0.017055 -0.011936 -0.006237  0.097213
# UC        0.070658 -0.181161  0.189406 -0.227304 -0.049460  0.107397
# DL        0.145425 -0.069361  0.410102 -0.186967 -0.165750  0.410031
# DS        0.004285  0.008452  0.016163 -0.004398  0.034349  0.040832
# DP        1.000000  0.038238  0.119892 -0.077758 -0.114084  0.175340
# ASTV      0.038238  1.000000 -0.293882  0.357497 -0.220427 -0.207599
# MSTV      0.119892 -0.293882  1.000000 -0.291935  0.028934  0.435393
# ALTV     -0.077758  0.357497 -0.291935  1.000000 -0.107712 -0.346460
# MLTV     -0.114084 -0.220427  0.028934 -0.107712  1.000000  0.058580
# Width     0.175340 -0.207599  0.435393 -0.346460  0.058580  1.000000
# Tendency -0.130395 -0.010927 -0.036857  0.036771  0.116361  0.081355
# NSP       0.294472  0.422652 -0.095139  0.365846 -0.113674 -0.067423
#
#           Tendency       NSP
# LB        0.236864  0.131843
# AC        0.032481 -0.316941
# FM       -0.018339  0.074054
# UC       -0.066610 -0.185411
# DL       -0.023569  0.025427
# DS       -0.015398  0.065400
# DP       -0.130395  0.294472
# ASTV     -0.010927  0.422652
# MSTV     -0.036857 -0.095139
# ALTV      0.036771  0.365846
# MLTV      0.116361 -0.113674
# Width     0.081355 -0.067423
# Tendency  1.000000 -0.106238
# NSP      -0.106238  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# #### Standardization-StandardScalar Mean=0 standard Deviation =1 Z-score ####
# #### Normalization-MinMaxScalar-Values in the range of 0 to 1 ####

# %% [markdown]
#   Standardize data (0 mean, 1 stdev)
#   !pip install scikit-learn    First time
#       1 Reposatory -Anaconda
#       2 Library-Sklearn
#       3 Module-preprocessing
#       4 Classes StandardScaler,MinMaxScaler

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %% [markdown]
# ###  Standard Scalar ###

# %%
sc=StandardScaler()

# %%
data=sc.fit_transform(df)
data
# Out:
# array([[-1.1842579 , -0.73329757, -0.1465333 , ..., -0.14979071,
#          1.05900541,  1.07917677],
#        [-0.11924572,  0.72000029, -0.1465333 , ...,  1.38789578,
#         -0.4901423 , -0.47249527],
#        [-0.0304947 ,  0.02352782, -0.1465333 , ...,  1.38789578,
#         -0.4901423 , -0.47249527],
#        ...,
#        [ 0.5907624 , -0.50995991, -0.1465333 , ..., -0.07989587,
#          1.05912003,  1.06438003],
#        [ 0.5907624 , -0.57864409, -0.1465333 , ..., -0.10319415,
#          1.05912003,  1.07917677],
#        [ 0.76826443, -0.36527743, -0.14931116, ..., -0.66235288,
#         -0.4901423 , -0.47249527]])

# %%
pd.DataFrame(sc.fit_transform(df))
# Out:
#             0         1          2         3         4         5        6   \
# 0    -1.184258 -0.733298  -0.146533 -1.314683 -0.567147 -0.017731 -0.20862
# 1    -0.119246  0.720000  -0.146533  0.595558  0.387339 -0.017731 -0.20862
# 2    -0.030495  0.023528  -0.146533  1.172279  0.426977 -0.017731 -0.20862
# 3     0.058256 -0.149932  -0.146533  1.003470  0.199131 -0.017731 -0.20862
# 4    -0.123840  0.750771  -0.146533  1.123674 -0.567147 -0.017731 -0.20862
# ...        ...       ...        ...       ...       ...       ...      ...
# 2121  0.590762 -0.733298  14.089450  0.908809 -0.567147 -0.017731 -0.20862
# 2122  0.590762 -0.556842  -0.146533  0.775114 -0.567147 -0.017731 -0.20862
# 2123  0.590762 -0.509960  -0.146533  0.740230 -0.567147 -0.017731 -0.20862
# 2124  0.590762 -0.578644  -0.146533  0.514830 -0.567147 -0.017731 -0.20862
# 2125  0.768264 -0.365277  -0.149311  1.103978 -0.567147 -0.017731 -0.20862
#
#             7         8         9         10        11        12        13
# 0     1.382490 -0.736672  1.543111 -0.757287 -0.149791  1.059005  1.079177
# 1    -1.594721  0.626938 -0.485186  0.272180  1.387896 -0.490142 -0.472495
# 2    -1.647886  0.626938 -0.485186  0.658230  1.387896 -0.490142 -0.472495
# 3    -1.647886  0.882615 -0.485186  1.893590  1.085018  1.059120 -0.472495
# 4    -1.647886  0.882615 -0.485186  1.494672  1.085018  1.059120 -0.472495
# ...        ...       ...       ...       ...       ...       ...       ...
# 2121  1.701477 -0.992349  0.694057 -0.139607 -0.708949 -0.490142  1.079177
# 2122  1.648313 -0.821897  0.552547 -0.152475 -0.103194  1.059120  1.079177
# 2123  1.701477 -0.821897  0.458208 -0.281159 -0.079896  1.059120  1.064380
# 2124  1.648313 -0.821897  0.788396 -0.165344 -0.103194  1.059120  1.079177
# 2125  1.435655 -0.821897  1.206187 -0.422710 -0.662353 -0.490142 -0.472495
#
# [2126 rows x 14 columns]

# %%
scaled_data=pd.DataFrame(data,columns=df.columns)
scaled_data
# Out:
#             LB        AC         FM        UC        DL        DS       DP  \
# 0    -1.184258 -0.733298  -0.146533 -1.314683 -0.567147 -0.017731 -0.20862
# 1    -0.119246  0.720000  -0.146533  0.595558  0.387339 -0.017731 -0.20862
# 2    -0.030495  0.023528  -0.146533  1.172279  0.426977 -0.017731 -0.20862
# 3     0.058256 -0.149932  -0.146533  1.003470  0.199131 -0.017731 -0.20862
# 4    -0.123840  0.750771  -0.146533  1.123674 -0.567147 -0.017731 -0.20862
# ...        ...       ...        ...       ...       ...       ...      ...
# 2121  0.590762 -0.733298  14.089450  0.908809 -0.567147 -0.017731 -0.20862
# 2122  0.590762 -0.556842  -0.146533  0.775114 -0.567147 -0.017731 -0.20862
# 2123  0.590762 -0.509960  -0.146533  0.740230 -0.567147 -0.017731 -0.20862
# 2124  0.590762 -0.578644  -0.146533  0.514830 -0.567147 -0.017731 -0.20862
# 2125  0.768264 -0.365277  -0.149311  1.103978 -0.567147 -0.017731 -0.20862
#
#           ASTV      MSTV      ALTV      MLTV     Width  Tendency       NSP
# 0     1.382490 -0.736672  1.543111 -0.757287 -0.149791  1.059005  1.079177
# 1    -1.594721  0.626938 -0.485186  0.272180  1.387896 -0.490142 -0.472495
# 2    -1.647886  0.626938 -0.485186  0.658230  1.387896 -0.490142 -0.472495
# 3    -1.647886  0.882615 -0.485186  1.893590  1.085018  1.059120 -0.472495
# 4    -1.647886  0.882615 -0.485186  1.494672  1.085018  1.059120 -0.472495
# ...        ...       ...       ...       ...       ...       ...       ...
# 2121  1.701477 -0.992349  0.694057 -0.139607 -0.708949 -0.490142  1.079177
# 2122  1.648313 -0.821897  0.552547 -0.152475 -0.103194  1.059120  1.079177
# 2123  1.701477 -0.821897  0.458208 -0.281159 -0.079896  1.059120  1.064380
# 2124  1.648313 -0.821897  0.788396 -0.165344 -0.103194  1.059120  1.079177
# 2125  1.435655 -0.821897  1.206187 -0.422710 -0.662353 -0.490142 -0.472495
#
# [2126 rows x 14 columns]

# %%
scaled_data.describe()
# Out:
#                  LB            AC           FM            UC           DL  \
# count  2.105000e+03  2.106000e+03  2126.000000  2.126000e+03  2126.000000
# mean   1.107164e-15  8.097353e-17     0.000000  2.673726e-17     0.000000
# std    1.000238e+00  1.000238e+00     1.000235  1.000235e+00     1.000235
# min   -7.233306e+00 -5.126221e+00    -7.264525 -5.783790e+00    -5.173355
# 25%   -6.517518e-01 -7.332976e-01    -0.146533 -7.605601e-01    -0.567147
# 50%   -3.049470e-02 -3.610671e-01    -0.146533  2.805349e-02    -0.567147
# 75%    5.907624e-01  5.537333e-01    -0.108523  6.423774e-01     0.417167
# max    7.158338e+00  8.052549e+00    14.089450  7.668770e+00     8.639971
#
#                  DS            DP          ASTV          MSTV          ALTV  \
# count  2.105000e+03  2.105000e+03  2.126000e+03  2.126000e+03  2.126000e+03
# mean  -8.438750e-18  6.751000e-18 -1.938451e-16 -2.673726e-17  2.673726e-17
# std    1.000238e+00  1.000238e+00  1.000235e+00  1.000235e+00  1.000235e+00
# min   -9.580716e+00 -6.578049e+00 -5.847880e+00 -6.787691e+00 -4.777628e+00
# 25%   -1.773110e-02 -2.086197e-01 -7.972539e-01 -5.662206e-01 -4.851858e-01
# 50%   -1.773110e-02 -2.086197e-01  1.065425e-01 -1.400925e-01 -4.851858e-01
# 75%   -1.773110e-02 -2.086197e-01  7.445164e-01  2.860356e-01  3.368085e-02
# max    1.910824e+01  1.253024e+01  6.114130e+00  1.059834e+01  8.099698e+00
#
#                MLTV         Width      Tendency           NSP
# count  2.105000e+03  2.105000e+03  2.105000e+03  2.105000e+03
# mean  -1.890280e-16  2.362850e-17  1.215180e-16  3.375500e-16
# std    1.000238e+00  1.000238e+00  1.000238e+00  1.000238e+00
# min   -7.590375e+00 -5.694781e+00 -5.137929e+00 -3.616164e+00
# 25%   -4.741838e-01 -7.788443e-01 -4.901423e-01 -4.724953e-01
# 50%   -1.138703e-01 -7.989587e-02 -4.901423e-01 -4.724953e-01
# 75%    3.365215e-01  6.889474e-01  1.059120e+00 -4.724953e-01
# max    1.198237e+01  6.676605e+00  4.157645e+00  5.734193e+00
